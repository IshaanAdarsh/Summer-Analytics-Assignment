# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2023! We hope you are excited to implement and test everything you have learnt up until now.<a href = "https://drive.google.com/file/d/1U73P58VAc4EXM98Or9feKnVx9I9FOP_L/view?usp=sharing"> The dataset</a> which you'll use includes information about Movies.**

# %% [markdown]
#  We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!
#
# Let's get started with importing numpy, pandas, seaborn and matplotlib!

# %% [markdown]
# Note - matplotlib should be imported with the command :
#
# **import matplotlib.pyplot as plt**

# %% [markdown]
# Start by importing all important libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Read** the csv file and assign it to a variable .

# %%
movies = pd.read_csv('/content/imdb_top_1000.csv')
movies.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# Display shape of dataframe

# %%
movies.shape
# Out:
# (1000, 16)

# %% [markdown]
# Print all columns of dataframe

# %%
movies.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# Remove the column 'Poster_Link' and update the dataframe.

# %%
movies.drop('Poster_Link', axis=1, inplace=True)
movies.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %% [markdown]
# Set the 'Series_Title' column as the index of dataframe

# %%
movies.set_index('Series_Title', inplace=True)
movies.head()
# Out:
#                          Released_Year Certificate  Runtime  \
# Series_Title
# The Shawshank Redemption          1994           A  142 min
# The Godfather                     1972           A  175 min
# The Dark Knight                   2008          UA  152 min
# The Godfather: Part II            1974           A  202 min
# 12 Angry Men                      1957           U   96 min
#
#                                          Genre  IMDB_Rating  \
# Series_Title
# The Shawshank Redemption                 Drama          9.3
# The Godfather                     Crime, Drama          9.2
# The Dark Knight           Action, Crime, Drama          9.0
# The Godfather: Part II            Crime, Drama          9.0
# 12 Angry Men                      Crime, Drama          9.0
#
#                                                                    Overview  \
# Series_Title
# The Shawshank Redemption  Two imprisoned men bond over a number of years...
# ...

# %% [markdown]
# Print a list of all the unique Genre

# %%
file_url = 'https://drive.google.com/uc?id=1U73P58VAc4EXM98Or9feKnVx9I9FOP_L'
movies = pd.read_csv(file_url)

# Get all unique genres
unique_genres = set()

# Iterate over each row in the DataFrame
for genres in movies['Genre']:
    # Split the genres by comma and add them to the set
    unique_genres.update(genres.split(','))

# Print the list of unique genres
print("List of unique genres:")
for genre in unique_genres:
    print(genre.strip())
# Out:
# List of unique genres:
# Sport
# Comedy
# Comedy
# Crime
# Family
# Western
# Animation
# Biography
# Adventure
# Fantasy
# Musical
# Adventure
# Thriller
# Thriller
# Mystery
# Film-Noir
# Mystery
# Sci-Fi
# Action
# Music
# Fantasy
# Film-Noir
# Drama
# War
# Crime
# History
# Horror
# Horror
# Romance
# Western
# Drama
# Biography
# Action
# Family

# %% [markdown]
# 1. What is the Number of Directors in the given dataset ?

# %%
movies['Director'].nunique()
# Out:
# 548

# %% [markdown]
# 2. What is the mean, median and standard deviation of IMDB rating in the dataset ?

# %%
movies.IMDB_Rating.describe()
# Out:
# count    1000.000000
# mean        7.949300
# std         0.275491
# min         7.600000
# 25%         7.700000
# 50%         7.900000
# 75%         8.100000
# max         9.300000
# Name: IMDB_Rating, dtype: float64

# %% [markdown]
# 3. Which director has directed the most number of movies?

# %%
director_counts = movies['Director'].value_counts()
most_common_director = director_counts.idxmax()
num_movies = director_counts.max()

print("Director with the most number of movies:", most_common_director)
print("Number of movies directed:", num_movies)
# Out:
# Director with the most number of movies: Alfred Hitchcock
# Number of movies directed: 14

# %% [markdown]
# 4. Name the Movie which has the highest Runtime ?

# %%
movies.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# Split_Genres      object
# dtype: object

# %%
movies['Runtime'] = pd.to_timedelta(movies['Runtime'])

highest_runtime_movie = movies.loc[movies['Runtime'].idxmax(), 'Series_Title']
highest_runtime = movies['Runtime'].max()

highest_runtime_str = str(highest_runtime)

print("Movie with the highest runtime:", highest_runtime_movie)
print("Runtime:", highest_runtime_str[:-3])
# Out:
# Movie with the highest runtime: Gangs of Wasseypur
# Runtime: 0 days 05:21

# %% [markdown]
# 5. How many movies are released after year 2000 and have IMDB rating > 8.5 ?

# %%
movies['Released_Year'] = pd.to_numeric(movies['Released_Year'], errors='coerce')

filtered_movies = movies[(movies['Released_Year'] > 2000) & (movies['IMDB_Rating'] > 8.5)]

num_movies = len(filtered_movies)

print("Number of movies released after 2000 with IMDb rating > 8.5:", num_movies)
# Out:
# Number of movies released after 2000 with IMDb rating > 8.5: 11

# %% [markdown]
# Using seaborn make different types of plots, observe the trend and answer the questions.
# 6. Make a countplot of Movies directed by all directors.

# %%
plt.figure(figsize=(10, 6))  

top_directors = movies['Director'].value_counts().nlargest(5).index

sns.countplot(data=movies[movies['Director'].isin(top_directors)], x='Director')

plt.xticks(rotation=90)  
plt.xlabel('Director')  
plt.ylabel('Count')  
plt.title('Number of Movies Directed by Top 5 Directors')  

plt.show()

# %% [markdown]
# 7. Make a plot to analyze distribution of IMDB rating?

# %%
plt.figure(figsize=(8, 6))  

sns.histplot(data=movies, x='IMDB_Rating', bins=10, kde=True)

plt.xlabel('IMDB Rating') 
plt.ylabel('Count')  
plt.title('Distribution of IMDB Ratings')  

plt.show()

# %% [markdown]
# 8. What type of Genre has the highest IMDB rating?

# %%
movies['Split_Genres'] = movies['Genre'].str.split(',')

exploded_genres = movies.explode('Split_Genres')

genre_avg_rating = exploded_genres.groupby('Split_Genres')['IMDB_Rating'].mean().sort_values(ascending=False)

top_genre = genre_avg_rating.idxmax()

plt.figure(figsize=(10, 6))
sns.barplot(x=genre_avg_rating.values, y=genre_avg_rating.index, palette='viridis')
plt.xlabel('Average IMDb Rating')
plt.ylabel('Genre')
plt.title('Average IMDb Rating by Genre')
plt.axvline(x=genre_avg_rating.loc[top_genre], color='red', linestyle='--', label='Highest Rating Genre')
plt.legend()
plt.show()

print("Genre with the highest IMDb rating:", top_genre)
# Out:
# Genre with the highest IMDb rating: Western

# %% [markdown]
# 9. Name the top 5 movies that have earned highest Meta score.

# %%
top_movies = movies.nlargest(5, 'Meta_score')

plt.figure(figsize=(10, 6))
sns.barplot(x='Series_Title', y='Meta_score', data=top_movies, palette='viridis')
plt.xlabel('Movie')
plt.ylabel('Meta Score')
plt.title('Top 5 Movies with Highest Meta Score')
plt.show()

# %% [markdown]
# 10. Of which Genre movie has the highest Runtime?

# %%
# Split the genres by comma and create a new column "Split_Genres"
movies['Split_Genres'] = movies['Genre'].str.split(',')

# Create a new DataFrame to store the exploded genres and their corresponding runtimes
genre_runtime = movies.explode('Split_Genres')

# Convert the runtime column to numeric values representing minutes
genre_runtime['Runtime_minutes'] = genre_runtime['Runtime'].dt.total_seconds() / 60

# Find the genre with the highest runtime
top_genre = genre_runtime.groupby('Split_Genres')['Runtime_minutes'].max().idxmax()

# Filter the DataFrame to get the movie with the highest runtime
movie_highest_runtime = genre_runtime[genre_runtime['Split_Genres'] == top_genre].iloc[0]

# Print the movie with the highest runtime and its runtime
print("Movie with the highest runtime:", movie_highest_runtime['Series_Title'])
print("Runtime:", movie_highest_runtime['Runtime'])

# Create a box plot to visualize the runtime distribution by genre
plt.figure(figsize=(10, 6))
sns.boxplot(x='Runtime_minutes', y='Split_Genres', data=genre_runtime, palette='viridis')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Genre')
plt.title('Runtime Distribution by Genre')
plt.show()
# Out:
# Movie with the highest runtime: The Intouchables
# Runtime: 0 days 01:52:00
